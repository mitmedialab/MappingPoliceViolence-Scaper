# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import mediacloud, datetime
import pandas as pd
import numpy as np
from mpv import config, mc

from bokeh.plotting import show, figure, output_file, ColumnDataSource, reset_output
from bokeh.layouts import gridplot
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0b0fc024-a4b1-405b-86eb-1b3b51229961">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# * controversy_id for 2013: 1421
# * controversy_id for 2014: 1326
# * controversy_id for 2015: 1394
# * controversy_id for 2016: 1408

# %%
# takes a long time - 30 - 40 minutes. skip this -- it's stored in the .csv in the next section.

day = datetime.date(2013,1,1)
week = datetime.timedelta(7)

dates = []
num_stories_about_victims = []
num_stories_in_mediacloud = []

while day < datetime.date(2016, 7, 13):
    # number of stories about victims of police violence in that week
    aboutvictims = mc.storyCount("{~ topic:1421} OR {~ topic:1326} OR {~ topic:1394} OR {~ topic:1408}", 
                                 solr_filter=[mc.publish_date_query( day, day+week )])
    num_stories_about_victims.append(aboutvictims['count'])
    
    # number of total stories in mediacloud in these media sets in that week
    total = mc.storyCount("(tags_id_media:(8875027 2453107 129 8878292 8878293 8878294))",
                          solr_filter=[mc.publish_date_query( day, day+week)])
    num_stories_in_mediacloud.append(total['count'])
    
    # the first day of that week
    dates.append(day)
    
    # print progress and increment to next week
    print(day, aboutvictims, total)
    day += week

# %%
storycounts = pd.DataFrame({'num_stories_about_victims':num_stories_about_victims,
                            'num_stories_in_mediacloud':num_stories_in_mediacloud},
                             index = dates)

# %%
storycounts.to_csv(r'data\stories-over-time.csv', encoding = 'utf-8')

# %% [markdown]
# # Read from csv so you don't have to re-run all those queries above

# %%
storycounts = pd.read_csv(r'data\stories-over-time.csv', index_col=0)
storycounts = storycounts[['num_stories_in_mediacloud','num_stories_about_victims']]
storycounts.index = storycounts.index.to_datetime()

# %% [markdown]
# # plotting

# %%
storycounts.plot(figsize=(15, 6))
plt.title('Story Counts per Week')
plt.ylabel('# of stories')
plt.savefig('storycountsperweek.png', bbox_inches='tight')

# %%
storycounts.plot(figsize=(15, 6), logy=True)
plt.title('Story Counts per Week (log scale)')
plt.ylabel('# of stories')
plt.savefig('storycountsperweek-log.png', bbox_inches='tight')

# %%
storycounts.plot(subplots=True, figsize=(15, 6))
plt.savefig('storycountsperweek-sep.png', bbox_inches='tight')

# %% [markdown]
# ## incidents of "black lives matter" or "BLM" in the corpora

# %%
day = datetime.date(2013,1,1)
week = datetime.timedelta(7)

dates = []
num_stories_with_BLM = []

while day < datetime.date(2016, 7, 13):
    # number of stories about victims of police violence in that week
    blm_stories = mc.storyCount('''({~ topic:1421} OR {~ topic:1326} OR {~ topic:1394} OR {~ topic:1408}) AND ("black lives matter" OR "blacklivesmatter")''', 
                                 solr_filter=[mc.publish_date_query( day, day+week )])
    num_stories_with_BLM.append(blm_stories['count'])
    
    # the first day of that week
    dates.append(day)
    
    # print progress and increment to next week
    print(day, blm_stories)
    day += week

# %%
stories_about_blm = pd.DataFrame({'num_stories_about_BLM' : num_stories_with_BLM},
                                   index = dates)
stories_about_blm.to_csv(r'data\stories-about-blm.csv', encoding = 'utf-8')

# %% [markdown]
# ## read from csv to you don't have the re-run the above

# %%
stories_about_blm = pd.read_csv(r'data\stories-about-blm.csv', index_col=0)
stories_about_blm.index = stories_about_blm.index.to_datetime()

# %%
stories_about_blm['num_stories_about_BLM'].plot(figsize=(15, 6))
plt.title('# stories about black lives matter per week')
plt.ylabel('# of stories')
plt.savefig('numstoriesperweek-aboutBLM.png', bbox_inches='tight')

# %%
stories_about_blm['num_stories_about_victims'] = storycounts['num_stories_about_victims']
stories_about_blm['normalized_num_stories_about_blm'] = stories_about_blm['num_stories_about_BLM'] / stories_about_blm['num_stories_about_victims']

# %%
stories_about_blm['normalized_num_stories_about_blm'].plot(figsize=(15, 6))
plt.title('normalized # stories about black lives matter per week')
plt.ylabel('# of stories')
plt.savefig('normalizednumstoriesperweek-aboutBLM.png', bbox_inches='tight')

# %%
stories_about_blm.plot(subplots=True, figsize=(15, 9))
plt.savefig('summary-aboutBLM.png', bbox_inches='tight')

# %% [markdown]
# ## in each story about a victim, how many references are there to prior victims?

# %%
# for each victim, build a big OR query of all prior victims
all_articles = pd.read_csv(r'data\article-dataset.csv', index_col=8)

desired_columns = ['query','date_of_death']

queries2013 = pd.read_csv(r'data\2013\mpv-total-story-counts.csv', index_col=0)[desired_columns]
queries2014 = pd.read_csv(r'data\2014\mpv-total-story-counts.csv', index_col=0)[desired_columns]
queries2015 = pd.read_csv(r'data\2015\mpv-total-story-counts.csv', index_col=0)[desired_columns]
queries2016 = pd.read_csv(r'data\2016\mpv-total-story-counts.csv', index_col=0)[desired_columns]
queries = pd.concat([queries2013, queries2014, queries2015, queries2016])
queries.sort_values('date_of_death', inplace=True)

# %%
story_ids = []
stories_about_person = []

query_of_all_prior_victims = []
stories_mentioning_prior_victims = []

for person in queries.index:
    
    # for each victim, build query of all prior victims, one by one
    
    priors = queries[queries['date_of_death'] < queries['date_of_death'][person]]
    query_of_priors = '(' + ' OR '.join(['(' + str(i) + ')' for i in priors['query']]) + ')'
    query_of_all_prior_victims.append(query_of_priors)

    # get list of all story_ids for each victim
    
    if person not in all_articles.index:
        stories_id_query = "(stories_id:())"
        story_ids.append(stories_id_query)
        
        stories_about_person.append(0)
        
    elif list(all_articles.index).count(person) == 1:
        stories_id_query = '(stories_id: (' + str(all_articles.loc[person]['stories_id']) + '))'
        story_ids.append(stories_id_query)
        
        stories_about_person.append(1)
        
    else:
        stories_id_query = ' '.join([str(i) for i in all_articles.loc[person]['stories_id']])
        stories_id_query = '(stories_id: (' + stories_id_query + '))'
        story_ids.append(stories_id_query)
        
        stories_about_person.append(len(all_articles.loc[person]['stories_id']))
        
    # query mediacloud for story counts about prior victims
    
    if stories_id_query == "(stories_id:())": # no stories
        stories_mentioning_prior_victims.append(0)
        
        print queries['date_of_death'][person], person, stories_about_person[-1], 0
        
    elif query_of_priors == '()': # no prior victims in this list        
        stories_mentioning_prior_victims.append(0)
        
        print queries['date_of_death'][person], person, stories_about_person[-1], 0
    
    else:         
        combinedquery = stories_id_query + ' AND ' + query_of_priors
        priorvictimsstorycount = mc.storyCount(combinedquery)
        
        stories_mentioning_prior_victims.append(priorvictimsstorycount['count'])
    
        print queries['date_of_death'][person], person, stories_about_person[-1], priorvictimsstorycount['count']
        
queries['story_ids'] = story_ids
queries['query_of_all_prior_victims'] = query_of_all_prior_victims
queries['stories_about_person'] = stories_about_person
queries['stories_mentioning_prior_victims'] = stories_mentioning_prior_victims
# Out:
# 2013-01-04 Xavier Tyrell Johnson 2 0
# 2013-01-13 Quintine Barksdale 0 0
# 2013-01-17 Steven Askew 0 0
# 2013-01-19 Donovan Thomas 0 0
# 2013-01-28 Anthony Dwayne Harris 0 0
# 2013-02-13 Kayla Moore 0 0
# 2013-02-16 Charles A. Baker Jr. 0 0
# 2013-03-10 Clinton Roebexar Allen 1 0
# 2013-03-22 Russell Lydell Smith 0 0
# 2013-04-04 Jermaine C. Coleman Jr. 0 0
# 2013-04-06 Wilbur Frederick Miller II 0 0
# 2013-04-06 Clanesha Rayuna Shaqwanda Hickmon 0 0
# 2013-04-15 Dason Peters 6 0
# 2013-04-15 Dylan Samuel-Peters 6 0
# 2013-04-20 Craig Demps 0 0
# 2013-04-21 Fred Bradford Jr. 0 0
# 2013-05-22 Julian Dawkins 6 0
# 2013-07-09 Antonio Johnson 0 0
# 2013-07-16 Daryll Blair 0 0
# 2013-07-18 Tyrone West 0 0
# 2013-07-21 Deomain Hayman 0 0
# 2013-07-22 Kyam Livingston 5 0
# 2013-07-23 Jason M. Nalls 1 0
# 2013-07-25 Dainell Simmons 2 0
# 2013-07-26 Larry Eugene Jackson Jr. 1 0
# 2013-07-28 Ryan L. Stokes 0 0
# 2013-07-30 Allen Desdunes 0 0
# 2013-07-31 Jermaine McBean 1 0
# 2013-08-08 Montrell Moss 0 0
# 2013-08-08 Jeffery B. Lilly Jr. 0 0
# 2013-08-15 Carlo Alcis 1 0
# 2013-08-16 Patrick Othro Sullivan 0 0
# 2013-08-19 Ronnie Ledesma Jr. 1 0
# 2013-08-31 Rickey Rozelle 0 0
# 2013-09-03 Brian Nichols 0 0
# 2013-09-04 Dontre Bennett 0 0
# 2013-09-05 Denis Reynoso 2 0
# 2013-09-07 Marlon Horton 0 0
# 2013-09-14 Jonathan A. Ferrell 81 0
# 2013-09-17 Barrington Williams 0 0
# 2013-09-24 Devell Johns 1 0
# 2013-09-29 Alexander Jamar "A.J." Marion 0 0
# 2013-10-02 Elijah Glay 0 0
# 2013-10-04 Jack Lamar Roberson 14 0
# 2013-10-04 Reginald Williams Jr. 1 0
# 2013-10-13 William Taylor 1 0
# 2013-10-13 Brandon Devone Smith 0 0
# 2013-10-21 Tracy Clyde 0 0
# 2013-10-27 William Alfred Harvey III 0 0
# 2013-10-29 Ronald Wood 0 0
# 2013-11-11 Abdul Kamal 0 0
# 2013-11-13 Willie James Williams 0 0
# 2013-11-19 Tyler Damon Woods 1 0
# 2013-11-27 Jason Akeem Lewis 0 0
# 2013-11-28 Shiateria Wimbash 0 0
# 2013-11-28 Patrelle J. Stokes 0 0
# 2013-12-29 Kendall Alexander 0 0
# 2014-01-01 Julias Michael Reese 0 0
# 2014-01-10 Jeffrey Ragland 4 0
# 2014-01-16 Jordan Baker 1 0
# 2014-02-04 Anesson Joseph 12 0
# 2014-02-05 Willie James Sams 0 0
# 2014-02-10 Leroy Turner 0 0
# 2014-02-10 Anthony Bartley 0 0
# 2014-02-10 Ernest Satterwhite 0 0
# 2014-02-14 D’Andre Berghardt Jr. 5 0
# 2014-02-16 Yvette Smith 3 0
# 2014-02-24 Kenneth Christopher Lucas 0 0
# 2014-02-27 Treon "Tree" Johnson 4 3
# 2014-02-28 Marquise Jones 0 0
# 2014-03-08 Emerson Clayton Jr. 0 0
# 2014-03-09 Victor White III 1 0
# 2014-03-17 Hallis Kinsey 0 0
# 2014-03-23 Willie Neall Harden 0 0
# 2014-03-25 DeAndre Lloyd Starks 1 0
# 2014-03-30 Zikarious Flint 6 0
# 2014-04-03 Eddie Ray Epperson 0 0
# 2014-04-11 Gregory Lewis Towns Jr 0 0
# 2014-04-11 Matthew Walker 0 0
# 2014-04-25 Tyrone Davis 0 0
# 2014-05-03 Jerome Dexter Christmas 0 0
# 2014-05-05 Justin Griffin 13 0
# 2014-05-07 George V. King 0 0
# 2014-05-07 Dominique Franklin Jr. 0 0
# 2014-05-08 Howard Wallace Bowe Jr. 1 0
# 2014-05-11 Lavoy Steed 0 0
# 2014-05-11 Tommy J. Yancy Jr. 3 0
# 2014-05-11 Leon Haywood 0 0
# 2014-05-13 Branndon Jefferson 0 0
# 2014-05-16 Justin Sullivan 2 0
# 2014-05-16 Quentin Byrd 2 0
# 2014-05-22 Craig J. McKinnis 0 0
# 2014-05-25 Montez Dewayne Hambric 1 0
# 2014-05-29 Duane Erick Strong 2 0
# 2014-05-30 Mark Anthony Blocker 2 0
# 2014-05-31 Sandy James McCall 0 0
# 2014-06-08 Emanuel Jean-Baptiste 0 0
# 2014-06-14 Jason Harrison 3 0
# 2014-06-22 Juan May 4 0
# 2014-06-23 Samuel Shields 2 0
# 2014-06-24 Antoine Dominique Hunter 1 0
# 2014-06-24 Lavon King 0 0
# 2014-06-27 Paul Ray Kemp Jr. 0 0
# 2014-06-29 Brian Demarcus West 0 0
# 2014-07-01 Jerry Brown 2 0
# 2014-07-03 Jacqueline Nichols 9 0
# 2014-07-05 Warren Robinson 10 0
# 2014-07-05 Christopher Jones 0 0
# 2014-07-09 Charles K. Goodridge 0 0
# 2014-07-10 Tyshawn Hancock 1 0
# 2014-07-17 Eric Garner 439 4
# 2014-07-17 Andre Milton 0 0
# 2014-07-22 Briatay McDuffie 0 0
# 2014-07-28 Steven Isby 0 0
# 2014-08-01 Daniel Pierre 0 0
# 2014-08-03 Jacorey Calhoun 1 0
# 2014-08-04 Amir Brooks 2 0
# 2014-08-05 Cedric Stanley 0 0
# 2014-08-05 John H. Crawford III 83 34
# 2014-08-05 Jeremey Lake 43 0
# 2014-08-05 Tyree Woodson 2 0
# 2014-08-06 Michael Laray Dozer 0 0
# 2014-08-09 Michael Brown 7149 304
# 2014-08-11 Robert Baltimore 0 0
# 2014-08-11 Dustin Keith Glover 0 0
# 2014-08-11 Ezell Ford 136 109
# 2014-08-12 Dante Parker 22 17
# 2014-08-13 Corey Levert Tanner 5 0
# 2014-08-14 Wally Flex 1 0
# 2014-08-17 Levon Leroy Love 0 0
# 2014-08-20 Arvel Douglas Williams 0 0
# 2014-08-22 Vernicia Woodard 10 0
# 2014-08-23 Briant Paula 7 1
# 2014-08-24 Rondre Hornbeak 2 0
# 2014-08-26 Cortez Washington 35 1
# 2014-08-29 Ronald Singleton 38 32
# 2014-09-12 Darrien Nathaniel Hunt 60 16
# 2014-09-13 Christopher Lee Lucas 1 0
# 2014-09-13 Ricky Deangelo Hinkle 0 0
# 2014-09-18 Charles Smith 19 1
# 2014-09-23 Cameron Tillman 11 1
# 2014-09-27 Eugene Williams 0 0
# 2014-09-28 Oliver Jarrod Gregoire 0 0
# 2014-10-04 Lashano J. Gilbert 4 0
# 2014-10-06 Balantine Mbegbu 0 0
# 2014-10-07 Iretha Lilly 1 0
# 2014-10-07 Latandra Ellington 12 1
# 2014-10-08 VonDerrit D. Myers Jr. 310 231
# 2014-10-12 Ronald Johnson 0 0
# 2014-10-17 Adam Ardett Madison 1 0
# 2014-10-23 Michael Ricardo Minor 1 0
# 2014-10-25 Florence White 0 0
# 2014-10-27 Christopher Mason McCray 0 0
# 2014-10-28 Kaldrick Donald 0 0
# 2014-11-01 John T. Wilson III 0 0
# 2014-11-10 David Yearby 0 0
# 2014-11-13 Tanisha N. Anderson 9 4
# 2014-11-19 Keara Crowder 1 0
# 2014-11-20 Akai Gurley 169 91
# 2014-11-22 Tamir E. Rice 619 333
# 2014-11-25 Eric Ricks 2 0
# 2014-12-02 Rumain Brisbon 61 29
# 2014-12-10 Travis Faison 0 0
# 2014-12-13 Leo Blackmon Jr. 0 0
# 2014-12-14 Asia Roundtree 0 0
# 2014-12-15 Dennis Grisgby 0 0
# 2014-12-19 Terrell Beasley 4 0
# 2014-12-28 David Andre Scott 2 0
# 2014-12-30 Jerame C. Reid 2 2
# 2015-01-01 Matthew Ajibade 4 0
# 2015-01-05 Frank Smart 1 0
# 2015-01-06 Brian Pickett 1 0
# 2015-01-06 Leslie Sapp III 1 0
# 2015-01-07 Andre Larone Murphy Sr. 0 0
# 2015-01-08 Artago Damon Howard 0 0
# 2015-01-22 Tiano Meton 1 0
# 2015-01-26 Alvin Haynes 0 0
# 2015-02-05 Jeremy Lett 0 0
# 2015-02-08 Natasha McKenna 6 1
# 2015-02-15 Lavall Hall 12 1
# 2015-02-18 Janisha Fonville 0 0
# 2015-02-20 Terry Price 0 0
# 2015-02-22 Calvon A. Reid 5 0
# 2015-02-28 Thomas Allen 3 2
# 2015-03-01 DeOntre L. Dorsey 0 0
# 2015-03-01 Darrell "Hubbard" Gatewood 0 0
# 2015-03-01 Charly 'Africa' Keunang 120 31
# 2015-03-06 Bernard Moore 1 0
# 2015-03-06 Naeschylus Vinzant 6 2
# 2015-03-06 Tony Robinson 257 81
# 2015-03-09 Anthony Hill 50 26
# 2015-03-10 Terrance Moxley 0 0
# 2015-03-12 Bobby Gross 2 0
# 2015-03-12 Jonathan Paul 1 0
# 2015-03-17 Askari Roberts 0 0
# 2015-03-19 Brandon Jones 7 4
# 2015-03-22 Denzel Brown 3 0
# 2015-03-24 Nicholas Thomas 18 7
# 2015-03-29 Jason Moland 0 0
# 2015-03-30 Dominick R. Wise 1 0
# 2015-03-31 Phillip White 18 5
# 2015-04-02 Eric Courtney Harris 210 18
# 2015-04-02 Donald "Dontay" Ivy 2 1
# 2015-04-04 Walter Scott 1084 317
# 2015-04-14 Colby Robinson 8 0
# 2015-04-15 Frank 'Trey' Shephard III 2 0
# 2015-04-16 Darrell Brown 1 0
# 2015-04-18 Brian Acton 0 0
# 2015-04-19 Freddie Gray 3815 567
# 2015-04-19 Norman Cooper 0 0
# 2015-04-21 Samuel Harrell 0 0
# 2015-04-22 William Chapman 2 0
# 2015-04-23 Terry Lee Chatman 0 0
# 2015-04-24 Gregory Daquan Harris 0 0
# 2015-04-24 Lashonda Ruth Belk 0 0
# 2015-04-25 David Felix 1 0
# 2015-04-27 Terrance Kellom 7 3
# 2015-04-28 Rashod Bryan Overstreet 0 0
# 2015-04-28 Bryan Overstreet 0 0
# 2015-05-03 Reginald L. Moore Sr. 0 0
# 2015-05-05 Brendon Glenn 19 5
# 2015-05-06 Nuwnah Laroche 0 0
# 2015-05-06 Jason Champion 0 0
# 2015-05-08 Sam Holmes 0 0
# 2015-05-12 D'Angelo Reyes Stallworth 0 0
# 2015-05-12 Dajuan Graham 2 0
# 2015-05-13 Lorenzo Hayes 0 0
# 2015-05-21 Markus Clark 3 0
# 2015-05-31 Curtis Jordan 0 0
# 2015-05-31 Richard Davis 7 2
# 2015-06-08 Ross Anthony 2 0
# 2015-06-11 Fritz Severe 3 0
# 2015-06-13 Alan Craig Williams 0 0
# 2015-06-15 Kris Jackson 0 0
# 2015-06-16 Jermaine Benjamin 2 0
# 2015-06-20 Kevin Bajoie 1 0
# 2015-06-20 Zamiel Kivon Crawford 1 0
# 2015-06-25 Spencer McCain 1 0
# 2015-07-01 Kevin Judson 0 0
# 2015-07-02 Victo Larosa III 0 0
# 2015-07-08 Jonathan Sanders 30 8
# 2015-07-10 Freddie Blue 0 0
# 2015-07-11 George Mann 0 0
# 2015-07-12 Salvado Ellswood 1 0
# 2015-07-13 Sandra Bland 962 150
# 2015-07-17 Albert Davis 0 0
# 2015-07-17 Darrius Stewart 11 1
# 2015-07-19 Samuel DuBose 312 53
# 2015-07-20 Billy Ray Davis 1 1
# 2015-07-22 Michael Sabbie 0 0
# 2015-07-25 Brian Day 1 0
# 2015-08-06 Troy Robinson 1 0
# 2015-08-07 Christian Taylor 271 96
# 2015-08-14 Asshams Manley 1 0
# 2015-08-19 Mansur Ball-Bey 112 65
# 2015-08-27 Bertrand Davis 0 0
# 2015-08-27 Wendell Hall 0 0
# 2015-08-28 Felix Kumi 20 0
# 2015-08-31 James Carney III 0 0
# 2015-09-01 Tyree Crawford 0 0
# 2015-09-05 Lavante Biggs 0 0
# 2015-09-05 India Kager 8 0
# 2015-09-07 Wayne Wheeler 0 0
# 2015-09-23 Keith Harrison McLeod 22 1
# 2015-09-28 Junior Prosper 3 0
# 2015-09-29 James McBride 2 0
# 2015-10-03 Christopher Kimble 2 0
# 2015-10-11 Jason Day 2 0
# 2015-10-16 Ricky Ball 0 0
# 2015-10-17 Paterson Brown Jr 19 0
# 2015-10-17 Rayshaun Cole 0 0
# 2015-10-20 Lamontez Jones 1 0
# 2015-10-24 Dominic Hutchinson 0 0
# 2015-10-26 Kevin Brunson 6 0
# 2015-10-27 Anthony Ashford 0 0
# 2015-10-31 Bennie Lee Tignor 1 0
# 2015-10-31 Yvens Seide 1 0
# 2015-11-01 Alonzo Smith 9 0
# 2015-11-09 Antonio Henry 1 0
# 2015-11-09 Adarius Brown 1 0
# 2015-11-11 Michael Lee Marshall 9 0
# 2015-11-12 Stephen L. Tooson 0 0
# 2015-11-15 Richard Perkins 1 0
# 2015-11-15 Jamar Clark 701 39
# 2015-11-17 Chandra Weaver 0 0
# 2015-11-18 Tiara Thomas 0 0
# 2015-11-18 Cornelius Brown 2 1
# 2015-11-19 Nathaniel Pickett 0 0
# 2015-12-08 Miguel Espinal 16 1
# 2015-12-19 Roy Nelson 1 0
# 2015-12-20 Leroy Browning 0 0
# 2015-12-21 Michael Noel 4 0
# 2015-12-21 Bobby Daniels 15 1
# 2015-12-23 Kevin Matthews 13 2
# 2015-12-25 Bettie Jones 407 33
# 2015-12-26 Quintonio LeGrier 416 390
# 2015-12-31 Keith Childress 23 2
# 2016-01-04 Eric John Senegal 0 0
# 2016-02-01 Peter John 3 0
# 2016-02-03 Randy Nelson 1 0
# 2016-02-04 Antronie Scott 33 0
# 2016-02-05 Wendell Celestine Jr 0 0
# 2016-02-08 David Joseph 21 1
# 2016-02-13 Calin Roquemore 0 0
# 2016-02-13 Dyzhawn L. Perkins 20 0
# 2016-02-17 Paul Gaston 15 5
# 2016-02-21 Marquintan Sandlin 2 0
# 2016-02-24 Christopher Davis 0 0
# 2016-02-25 Greg Gunn 42 0
# 2016-02-26 Kionte Desean Spencer 4 0
# 2016-02-29 Akiel Denkins 82 1
# 2016-03-10 Arteair Porter Jr 0 0
# 2016-03-12 Peter Gaines 3 0
# 2016-03-12 Marco Loud 0 0
# 2016-03-17 Scott Bennett 1 0
# 2016-03-17 Christopher Nelms 1 0
# 2016-03-19 Torrey Robinson 3 0
# 2016-03-19 India Beaty 24 0
# 2016-03-20 Robert Dentmond 6 0
# 2016-03-24 Dominique Silva 1 0
# 2016-04-04 Darius Robinson 3 0
# 2016-04-05 Kevin Hicks 5 0
# 2016-04-13 Rodney Watts 0 0
# 2016-04-15 Robert Howard 0 0
# 2016-04-23 Demarcus Semer 23 0
# 2016-04-23 Willie Tillman 0 0
# 2016-04-28 Ashtain Barnes 0 0
# 2016-05-01 Charlin Charles 5 0
# 2016-05-07 Lionel Gibson 2 0
# 2016-05-09 Arthur Williams Jr 1 0
# 2016-05-19 Jessica Nelson-Williams 18 3
# 2016-05-22 Vernell Bing 3 0
# 2016-05-22 Michael Eugene Wilson Jr. 10 0
# 2016-05-25 Doll Pierre-Louis 4 0
# 2016-05-26 Devonte Gates 4 0
# 2016-05-28 Ollie Brooks 9 0
# 2016-06-02 Willie 'Meek' James 6 0
# 2016-06-09 John Brisco 0 0
# 2016-06-18 Antwun Shumpert 11 0
# 2016-06-19 Clarence Howard 10 0
# 2016-06-22 Deravis Caine Rogers 0 0
# 2016-06-27 Sherman Evans 6 0
# 2016-06-29 Tyrone Reado 0 0

# %%
queries['normalized_stories_mentioning_prior_victims'] = queries['stories_mentioning_prior_victims'] / queries['stories_about_person']
queries.to_csv(r'data\mentions-of-prior-incidents.csv', encoding = 'utf-8')

# %% [markdown]
# ## read from csv so you don't have to rerun the query

# %%
queries = pd.read_csv(r'data\mentions-of-prior-incidents.csv', index_col=0)
queries['date_of_death'] = pd.to_datetime(queries['date_of_death'])

# %%
toplot = queries[['date_of_death', 'stories_about_person', 'stories_mentioning_prior_victims', 'normalized_stories_mentioning_prior_victims']]
toplot['index'] = range(len(queries['query']))

fig = plt.figure(figsize=(15,4))
plt.scatter(list(toplot['index']), list(toplot['normalized_stories_mentioning_prior_victims']))
# Out:
# C:\Users\Allan\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
def nameplot(series, namelist, colors = 'black', title = None, xlabel = None, ylabel = None, 
             plot_height = 450, plot_width=900, yaxistype = 'linear'):
    '''takes a pandas Series, indexed by qb name, generates color-coded plot of those series
    with names on the x-axis and values on the y-axis.
    returns a Bokeh plot.'''

    plot = figure(x_range = namelist, title = title,
                          plot_height = plot_height, plot_width = plot_width, tools = "save, box_zoom, xpan, reset",
                          y_axis_type = yaxistype)

    plot.circle(series.index.values, series, 
                        size=5, fill_color=colors, line_color=None)
    plot.xaxis.axis_label = xlabel
    plot.xaxis.major_label_orientation = np.pi/2
    plot.yaxis.axis_label = ylabel
    
    return plot

mentionsofpriors = nameplot(toplot['normalized_stories_mentioning_prior_victims'], 
                            list(toplot.index.values),
                            title = 'Fraction of stories mentioning prior victims')

storiesaboutperson = nameplot(toplot['stories_about_person'],
                              mentionsofpriors.x_range,
                              title = 'Total # stories about person',
                              xlabel = 'Victim',
                              plot_height = 200,
                              yaxistype = 'log',
                              colors = 'blue')
storiesaboutperson.xaxis.visible = False
output_file('stories_about_prior_victims.html')
show(gridplot([storiesaboutperson],[mentionsofpriors]))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="57668b4c-1153-4cc9-8238-f1334f4435f5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#57668b4c-1153-4cc9-8238-f1334f4435f5").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("57668b4c-1153-4cc9-8238-f1334f4435f5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '57668b4c-1153-4cc9-8238-f1334f4435f5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"01ec7bbb-8972-4279-9de6-f2c115a55754":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"321b4e24-f902-4252-a13e-a88630f7b651","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"fd14af31-3c1a-4b8a-b593-119e29614eda","type":"DataRange1d"},{"attributes":{"callback":null,"factors":["Xavier Tyrell Johnson","Quintine Barksdale","Steven Askew","Donovan Thomas","Anthony Dwayne Harris","Kayla Moore","Charles A. Baker Jr.","Clinton Roebexar Allen","Russell Lydell Smith","Jermaine C. Coleman Jr.","Wilbur Frederick Miller II","Clanesha Rayuna Shaqwanda Hickmon","Dason Peters","Dylan Samuel-Peters","Craig Demps","Fred Bradford Jr.","Julian Dawkins","Antonio Johnson","Daryll Blair","Tyrone West","Deomain Hayman","Kyam Livingston","Jason M. Nalls","Dainell Simmons","Larry Eugene Jackson Jr.","Ryan L. Stokes","Allen Desdunes","Jermaine McBean","Montrell Moss","Jeffery B. Lilly Jr.","Carlo Alcis","Patrick Othro Sullivan","Ronnie Ledesma Jr.","Rickey Rozelle","Brian Nichols","Dontre Bennett","Denis Reynoso","Marlon Horton","Jonathan A. Ferrell","Barrington Williams","Devell Johns","Alexander Jamar \"A.J.\" Marion","Elijah Glay","Jack Lamar Roberson","Reginald Williams Jr.","William Taylor","Brandon Devone Smith","Tracy Clyde","William Alfred Harvey III","Ronald Wood","Abdul Kamal","Willie James Williams","Tyler Damon Woods","Jason Akeem Lewis","Shiateria Wimbash","Patrelle J. Stokes","Kendall Alexander","Julias Michael Reese","Jeffrey Ragland","Jordan Baker","Anesson Joseph","Willie James Sams","Leroy Turner","Anthony Bartley","Ernest Satterwhite","D\u2019Andre Berghardt Jr.","Yvette Smith","Kenneth Christopher Lucas","Treon \"Tree\" Johnson","Marquise Jones","Emerson Clayton Jr.","Victor White III","Hallis Kinsey","Willie Neall Harden","DeAndre Lloyd Starks","Zikarious Flint","Eddie Ray Epperson","Gregory Lewis Towns Jr","Matthew Walker","Tyrone Davis","Jerome Dexter Christmas","Justin Griffin","George V. King","Dominique Franklin Jr.","Howard Wallace Bowe Jr.","Lavoy Steed","Tommy J. Yancy Jr.","Leon Haywood","Branndon Jefferson","Justin Sullivan","Quentin Byrd","Craig J. McKinnis","Montez Dewayne Hambric","Duane Erick Strong","Mark Anthony Blocker","Sandy James McCall","Emanuel Jean-Baptiste","Jason Harrison","Juan May","Samuel Shields","Antoine Dominique Hunter","Lavon King","Paul Ray Kemp Jr.","Brian Demarcus West","Jerry Brown","Jacqueline Nichols","Warren Robinson","Christopher Jones","Charles K. Goodridge","Tyshawn Hancock","Eric Garner","Andre Milton","Briatay McDuffie","Steven Isby","Daniel Pierre","Jacorey Calhoun","Amir Brooks","Cedric Stanley","John H. Crawford III","Jeremey Lake","Tyree Woodson","Michael Laray Dozer","Michael Brown","Robert Baltimore","Dustin Keith Glover","Ezell Ford","Dante Parker","Corey Levert Tanner","Wally Flex","Levon Leroy Love","Arvel Douglas Williams","Vernicia Woodard","Briant Paula","Rondre Hornbeak","Cortez Washington","Ronald Singleton","Darrien Nathaniel Hunt","Christopher Lee Lucas","Ricky Deangelo Hinkle","Charles Smith","Cameron Tillman","Eugene Williams","Oliver Jarrod Gregoire","Lashano J. Gilbert","Balantine Mbegbu","Iretha Lilly","Latandra Ellington","VonDerrit D. Myers Jr.","Ronald Johnson","Adam Ardett Madison","Michael Ricardo Minor","Florence White","Christopher Mason McCray","Kaldrick Donald","John T. Wilson III","David Yearby","Tanisha N. Anderson","Keara Crowder","Akai Gurley","Tamir E. Rice","Eric Ricks","Rumain Brisbon","Travis Faison","Leo Blackmon Jr.","Asia Roundtree","Dennis Grisgby","Terrell Beasley","David Andre Scott","Jerame C. Reid","Matthew Ajibade","Frank Smart","Brian Pickett","Leslie Sapp III","Andre Larone Murphy Sr.","Artago Damon Howa ...

# %%
queries.loc['Treon "Tree" Johnson']
# Out:
# query                                          (Treon AND Johnson OR "Tre Johnson" OR "Tree J...
# date_of_death                                                                2014-02-27 00:00:00
# story_ids                                      (stories_id: (208469092 208494849 490627450 28...
# query_of_all_prior_victims                     ((("Xavier Tyrell Johnson" OR "Xavier T Johnso...
# stories_about_person                                                                           4
# stories_mentioning_prior_victims                                                               3
# normalized_stories_mentioning_prior_victims                                                 0.75
# Name: Treon "Tree" Johnson, dtype: object
